# %%
import keras_ocr 

pipeline = keras_ocr.pipeline.Pipeline()
import pandas as pd 
import numpy as np 

from glob import glob
from tqdm.notebook import tqdm 

import matplotlib.pyplot as plt 
from PIL import Image
# Out:
# Looking for C:\Users\Abhishek Patil\.keras-ocr\craft_mlt_25k.h5
# Looking for C:\Users\Abhishek Patil\.keras-ocr\crnn_kurapan.h5

# %%
plt.imshow(plt.imread('./download.png'))
img='download.png'

# %%
results = pipeline.recognize([img])
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step

# %%
keras_ocr.tools.drawAnnotations(plt.imread(img), results[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <AxesSubplot:>

# %%
textInImage=[]
for text, box in results[0]:
   textInImage.append(text)
print(textInImage)
# Out:
# ['image', 'to', 'text', 'how', 'to', 'extract', 'text', 'from', 'an', 'image']
